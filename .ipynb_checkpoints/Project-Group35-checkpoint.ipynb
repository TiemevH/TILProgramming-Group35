# %% [markdown]
# # Project Group -
#
# Members: Tieme van Hijum, Emma van den Brink, Sil Havinga
#
# Student numbers: 4923588, 5136008, 4730321

# %% [markdown]
# # Research Objective
#
# *Requires data modeling and quantitative research in Transport, Infrastructure & Logistics*

# %% [markdown]
# # Introduction
#
# Access to healthcare is a fundamental right in modern society. Every resident should be within reach of timely medical assistance. In the 1960s, a standard was established in the Netherlands stipulating that every citizen should be able to reach a hospital within 45 minutes in the event of an emergency (Skipr Redactie, 2013). This standard breaks down into three key components: 15 minutes for emergency response time, 5 minutes for care at the scene, and 25 minutes for transport to a hospital. However, this target has been scrutinized, with reports indicating that the threshold is rarely met in some regions, while it is occasionally missed in others (Centraal Bureau voor de Statistiek, 2009).
#
# This study explores the development over time in the proportion of the population that falls outside this maximum distance to a hospital. Using data modeling and quantitative research, this investigation will analyze the trends in hospital accessibility across different regions of the Netherlands. Additionally, it aims to provide insights into how changes in population density, hospital location, and infrastructure impact the ability to meet the 45-minute target, with implications for future policy decisions.
#
# # Method
#
# The structure of this document is as follows: first, several regions of The Netherlands are shown in a map. Data is available for these regions, such as the number of people living there and their average distance to a hospital. Next, a color scheme is added to show how far away the nearest hospital is...... !!!!! CHECK THIS AND FINISH THE STRUCTURE OF THE DOCUMENT !!!!
#
#
# MOVE THE INFORMATION BELOW TO THE CELL AT THE BOTOM???
#
# Data Sources:
#  - CBS: Per municipality, district and neighborhood; proximity to hospital and population. https://www.cbs.nl/nl-nl/reeksen/publicatie/nabijheidsstatistieken-per-wijk-buurt
#  - Optionally, data for hospital locations over time
#
# Time Scale:
#  - Data is available from 2007 until 2022, but the geography has changed over that time.

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib
import plotly.express as px

# %%
#Setting up an empty dictionary of all datasets, so each dataset can be individually called when needed
dataset = dict()
years = range(2007,2023)
for year in years:
    #First, loading in the shapefile
    dataset[year] = gpd.read_file(f'AreaGeodata/Wijken{year}.shp')
    #Second, setting the areacode as the index, for convention
    dataset[year] = dataset[year].set_index('statcode')
    #Third, the proximities per area are loaded separately, sorting by areacode so it's guaranteed that
    #the indexes match
    proximities = pd.read_csv(f'ProximitiesPerArea/Proximities{year}.csv',
                              index_col = 'WijkenEnBuurten').sort_values(by = 'WijkenEnBuurten')
    
    inhabitants = pd.read_csv(f'PopulationData/Bewoners{year}.csv',
                              index_col = 'WijkenEnBuurten').sort_values(by = 'WijkenEnBuurten')
    
    #Lastly, adding the proximities per area as a new column to the dataset
    dataset[year]['AfstandTotZiekenhuis_11'] = proximities['AfstandTotZiekenhuis_11'].tolist()
    dataset[year]['AantalInwoners_5'] = inhabitants['AantalInwoners_5'].tolist()
    dataset[year]['Year'] = year

# %%
#An example of a plot of just the areas
dataset[2007].plot(figsize = (10,30))
plt.xticks([])
plt.yticks([]);

# %%
#Example of how to plot the proximity data on a logarithmic scale to make visualisation better
dataset[2022].plot(figsize = (10,10), column='AfstandTotZiekenhuis_11', legend = True, cmap='RdYlGn_r',
                   norm=matplotlib.colors.LogNorm(vmin=dataset[2022].AfstandTotZiekenhuis_11.min(),
                                                  vmax=dataset[2022].AfstandTotZiekenhuis_11.max(),
                                                  clip = True))
plt.xticks([])
plt.yticks([]);

# %%
#Example of a plot where every value bigger than 25 km is made black, this makes the map easier to read
fig, ax = plt.subplots(figsize = (10,10))

dataset[2022][dataset[2022]['AfstandTotZiekenhuis_11'] < 25].plot(ax=ax, vmax=25,
                                                                  column='AfstandTotZiekenhuis_11',
                                                                  legend=True, cmap='RdYlGn_r')
dataset[2022][dataset[2022]['AfstandTotZiekenhuis_11'] >= 25].plot(ax=ax, color='black', legend=True)
plt.xticks([])
plt.yticks([])

plt.show();

# %%
fig, axs = plt.subplots(nrows=4, ncols=4, sharex='col', sharey='row', figsize = (12,12))

for i in range(0,4):
    for j in range(0,4):
        dataset[2007 + i*4 + j][dataset[2007 + i*4 + j]\
               ['AfstandTotZiekenhuis_11'] < 25].plot(ax=axs[i][j], vmax=25,
                                                      column='AfstandTotZiekenhuis_11',
                                                      legend=False, cmap='RdYlGn_r')
        dataset[2007 + i*4 + j][dataset[2007 + i*4 + j]\
               ['AfstandTotZiekenhuis_11'] >= 25].plot(ax=axs[i][j], color='black', legend=False)
        axs[i][j].set_title(2007 + i*4 + j)
        axs[i][j].set_xticks([])
        axs[i][j].set_yticks([])
        
fig.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9, wspace=0, hspace=None)
im = plt.gca().get_children()[0]
cax = fig.add_axes([0.925,0.1,0.03,0.8]) 
fig.colorbar(im, cax=cax)        
plt.show();

# %%
fulldataset = pd.concat([dataset[2007], dataset[2008], dataset[2009], dataset[2010],
                        dataset[2011], dataset[2012], dataset[2013], dataset[2014],
                        dataset[2015], dataset[2016], dataset[2017], dataset[2018],
                        dataset[2019], dataset[2020], dataset[2021], dataset[2022]])
fulldataset.head()
#print(fulldataset)

#fig = px.bar(dfpop, x='pop', y='continent', color='continent')


#fig.show()
# Out:
#                       statnaam  \
# statcode
# WK000300               Wijk 00
# WK000500               Wijk 00
# WK000700  Wijk 00 Bellingwolde
# WK000701          Wijk 01 Oost
# WK000702       Wijk 02 Blijham
#
#                                                    geometry  \
# statcode
# WK000300  POLYGON ((251265.220 594389.100, 251430.765 59...
# WK000500  POLYGON ((235652.627 595015.438, 235916.260 59...
# WK000700  POLYGON ((272256.378 575634.560, 272465.550 57...
# WK000701  POLYGON ((274502.406 568475.500, 274538.812 56...
# WK000702  POLYGON ((269997.000 566028.000, 270040.406 56...
#
#           AfstandTotZiekenhuis_11  Year gm_code
# statcode
# WK000300                      3.9  2007     NaN
# WK000500                     10.3  2007     NaN
# WK000700                     11.9  2007     NaN
# WK000701                     13.9  2007     NaN
# WK000702                      7.1  2007     NaN

# %%
#Example of how to plot the inhabitant data on a logarithmic scale to make visualisation better

dataset[2022].plot(figsize = (10,10), column='AantalInwoners_5', legend = True, cmap='RdYlGn_r',
                   norm=matplotlib.colors.LogNorm(vmin=dataset[2022].AantalInwoners_5.min()+0.1,
                                                  vmax=dataset[2022].AantalInwoners_5.max(),
                                                  clip = True))
plt.xticks([])
plt.yticks([]);
# Out:
# 95625

# %%
#Example of a plot where every value smaller than 10 inhabitants is made gray since clearly this is an area where
#the available data is incorrect or where there are no inhabitants, this makes the map easier to read
fig, ax = plt.subplots(figsize = (10,10))

dataset[2022][dataset[2022]['AantalInwoners_5'] <= 40000].plot(ax=ax, vmin=10,
                                                                  column='AantalInwoners_5',
                                                                  legend=True, cmap='RdYlGn_r')
dataset[2022][dataset[2022]['AantalInwoners_5'] < 10].plot(ax=ax, color='gray', legend=True)
dataset[2022][dataset[2022]['AantalInwoners_5'] > 40000].plot(ax=ax, color='black', legend=True)
plt.xticks([])
plt.yticks([])

plt.show();

# %%
data = dataset[2022][['AantalInwoners_5', 'AfstandTotZiekenhuis_11']]
#print(data)
sorted_data = data.sort_values('AfstandTotZiekenhuis_11')
#print(sorted_data)
filtered_data_a = sorted_data[sorted_data['AfstandTotZiekenhuis_11'] <=25]
filtered_data_b = sorted_data[sorted_data['AfstandTotZiekenhuis_11'] > 25]

plt.plot(filtered_data_a['AfstandTotZiekenhuis_11'], filtered_data_a['AantalInwoners_5'], '.', color='g', label='<25 km from nearest hospital')
plt.plot(filtered_data_b['AfstandTotZiekenhuis_11'], filtered_data_b['AantalInwoners_5'], '.', color='r', label='>25 km from nearest hospital')
plt.legend()
plt.xlabel('Distance to nearest hospital')
plt.ylabel('Neighbourhood Inhabitants')

for i in range(len(sorted_data)):
    if sorted_data['AfstandTotZiekenhuis_11'].iloc[i] > 25:
        print(f'{sorted_data['AfstandTotZiekenhuis_11'].index[i]}, {sorted_data['AantalInwoners_5'].iloc[i]}, {sorted_data['AfstandTotZiekenhuis_11'].iloc[i]}')

#plt.plot(sorted_data['AfstandTotZiekenhuis_11'], sorted_data['AantalInwoners_5'], '.')

plt.figure()

plt.step(sorted_data['AfstandTotZiekenhuis_11'], np.cumsum(sorted_data['AantalInwoners_5']), where='post')
# Out:
# WK196604, 2145, 25.1
# WK196602, 3230, 25.3
# WK197000, 12830, 25.8
# WK191106, 2445, 25.9
# WK197006, 2230, 26.5
# WK074403, 130, 27.0
# WK197012, 1815, 27.4
# WK196601, 3215, 29.4
# WK196603, 1430, 29.6
# WK197007, 740, 29.9
# WK197002, 1430, 30.7
# WK197001, 1645, 31.3
# WK197005, 2200, 33.3
# WK197004, 1140, 34.1
# WK009300, 2575, 35.0
# WK197003, 1770, 35.5
# WK009600, 1195, 36.0
# WK009301, 1305, 40.1
# WK009302, 295, 41.8
# WK009303, 145, 43.1
# WK009304, 500, 44.3
# WK006000, 3755, 46.5
# WK009305, 140, 47.0
# WK008800, 945, 57.7

# %%
from matplotlib.ticker import FuncFormatter

colors = plt.cm.jet(np.linspace(0, 1, len(range(2007,2023))))

for i, year in enumerate(range(2007, 2023)):   
    data = dataset[year][['AantalInwoners_5', 'AfstandTotZiekenhuis_11']]
    #print(data)
    sorted_data = data.sort_values('AfstandTotZiekenhuis_11')
    #print(sorted_data)
    #cumulative_pop = np.cumsum(sorted_data['AantalInwoners_5'])
    plt.step(sorted_data['AfstandTotZiekenhuis_11'], np.cumsum(sorted_data['AantalInwoners_5']), where='post', label=year, color=colors[i])
    
plt.legend()
plt.xlabel('Kilometers to Hospital')
plt.ylabel('Cumulative Amount of Inhabitants')

def format_func(value, tick_number):
    return f'{int(value):,}'
plt.gca().yaxis.set_major_formatter(FuncFormatter(format_func))

# %%
colors = plt.cm.jet(np.linspace(0, 1, len(range(2007,2023))))

for i, year in enumerate(range(2007, 2023)):   
    data = dataset[year][['AantalInwoners_5', 'AfstandTotZiekenhuis_11']]
    #print(data)
    filtered_data = data[data['AfstandTotZiekenhuis_11'] > 25]
    
    sorted_data = filtered_data.sort_values('AfstandTotZiekenhuis_11')
    #print(sorted_data)
    #cumulative_pop = np.cumsum(sorted_data['AantalInwoners_5'])
    plt.step(sorted_data['AfstandTotZiekenhuis_11'], np.cumsum(sorted_data['AantalInwoners_5']), where='post', label=year, color=colors[i])
    
    total_sum = sum(sorted_data['AantalInwoners_5'])
    total_inhabitants = sum(data['AantalInwoners_5'])
    print(f'In {year} a total of {total_sum} inhabitants ({total_sum/total_inhabitants*100:.2f} %) live >25 km away from the nearest hospital')

print(f'In 2016 plotseling meer inwoners zonder ziekenhuis in de buurt: https://nos.nl/artikel/2005786-ziekenhuis-de-sionsberg-ontslaat-alle-werknemers')
print(f'In 2010 polikliniek geopend in Lemmer')

plt.legend()
plt.xlabel('Kilometers to Hospital')
plt.ylabel('Cumulative Amount of Inhabitants')
# Out:
# In 2007 a total of 29640 inhabitants (0.18 %) live >25 km away from the nearest hospital
# In 2008 a total of 27510 inhabitants (0.17 %) live >25 km away from the nearest hospital
# In 2009 a total of 27560 inhabitants (0.17 %) live >25 km away from the nearest hospital
# In 2010 a total of 18515 inhabitants (0.11 %) live >25 km away from the nearest hospital
# In 2011 a total of 18310 inhabitants (0.11 %) live >25 km away from the nearest hospital
# In 2012 a total of 18305 inhabitants (0.11 %) live >25 km away from the nearest hospital
# In 2013 a total of 16845 inhabitants (0.10 %) live >25 km away from the nearest hospital
# In 2014 a total of 16685 inhabitants (0.10 %) live >25 km away from the nearest hospital
# In 2015 a total of 16600 inhabitants (0.10 %) live >25 km away from the nearest hospital
# In 2016 a total of 39630 inhabitants (0.23 %) live >25 km away from the nearest hospital
# In 2017 a total of 42435 inhabitants (0.25 %) live >25 km away from the nearest hospital
# In 2018 a total of 42400 inhabitants (0.25 %) live >25 km away from the nearest hospital
# In 2019 a total of 44130 inhabitants (0.26 %) live >25 km away from the nearest hospital
# In 2020 a total of 44135 inhabitants (0.25 %) live >25 km away from the nearest hospital
# In 2021 a total of 45435 inhabitants (0.26 %) live >25 km away from the nearest hospital
# In 2022 a total of 49250 inhabitants (0.28 %) live >25 km away from the nearest hospital
# In 2016 plotseling meer inwoners zonder ziekenhuis in de buurt: https://nos.nl/artikel/2005786-ziekenhuis-de-sionsberg-ontslaat-alle-werknemers
# In 2010 polikliniek geopend in Lemmer
# Text(0, 0.5, 'Cumulative Amount of Inhabitants')

# %% [markdown]
# # Conclusion
#
# bla bla bla
#
# # Discussion
#
# bla bla bla
#
# # References
#
# Centraal Bureau voor de Statistiek. (2009, 12 augustus). Meeste Nederlanders wonen binnen 5 kilometer van ziekenhuis. Centraal Bureau Voor de Statistiek. https://www.cbs.nl/nl-nl/nieuws/2009/33/meeste-nederlanders-wonen-binnen-5-kilometer-van-ziekenhuis
#
# Skipr Redactie. (2013, 22 oktober). De 45-minutengrens is niet meer van deze tijd. - Skipr. Skipr. https://www.skipr.nl/blog/de-45-minutengrens-is-niet-meer-van-deze-tijd/#:~:text=Ergens%20in%20de%20zestiger%20jaren,Hiervan%20is%2015%20min.

# %% [markdown]
# # Contribution Statement
#
# *Be specific. Some of the tasks can be coding (expect everyone to do this), background research, conceptualisation, visualisation, data analysis, data modelling*

# %% [markdown]
# **Tieme van Hijum**:
#
# **Emma van den Brink**:
#
# **Sil Havinga**:

# %% [markdown]
# # Data Used

# %% [markdown]
# # Data Pipeline
